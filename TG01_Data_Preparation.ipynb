# %% [markdown]
# # Data Preparation & Validation

# %% [markdown]
# ### step 1) Importing libraries and loading datasets

# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('data/raw/agentic_ai.csv')

# %%
df.head()
# Out:
#    agent_id           agent_type model_architecture deployment_environment  \
# 0  AG_01012      Project Manager             PaLM-2                 Server
# 1  AG_00758  Marketing Assistant       Mixtral-8x7B                 Hybrid
# 2  AG_00966            QA Tester       Mixtral-8x7B                 Server
# 3  AG_00480       Code Assistant            CodeT5+                 Hybrid
# 4  AG_01050            QA Tester        Falcon-180B                   Edge
#
#            task_category  task_complexity  autonomy_level  success_rate  \
# 0        Text Processing                5               3        0.4788
# 1        Decision Making                6               5        0.4833
# 2          Communication                2               4        0.8116
# 3       Creative Writing                8               6        0.3574
# 4  Planning & Scheduling                3               4        0.5706
#
#    accuracy_score  efficiency_score  ...  error_recovery_rate  \
# 0          0.6455            0.6573  ...               0.4999
# 1          0.5660            0.5844  ...               0.5580
# 2          0.8395            0.7650  ...               0.9196
# 3          0.4888            0.4742  ...               0.3809
# 4          0.7137            0.7209  ...               0.6717
#
#    multimodal_capability  edge_compatibility  privacy_compliance_score  \
# 0                  False               False                    0.9390
# 1                  False               False                    0.8281
# 2                  False               False                    0.7450
# 3                   True               False                    0.9653
# 4                  False                True                    0.9042
#
#    bias_detection_score            timestamp  data_quality_score  \
# 0                0.8061  2024-12-24 04:16:15              0.9510
# 1                0.7816  2024-12-24 04:16:15              0.7822
# 2                0.8214  2024-12-24 04:16:15              0.7621
# 3                0.8684  2024-12-24 04:16:15              0.8117
# 4                0.8417  2024-12-24 04:16:15              0.7762
#
#    performance_index  cost_efficiency_ratio  autonomous_capability_score
# 0            0.58236              50.203448                       64.993
# 1            0.53844              69.030769                       89.060
# 2            0.80599             127.934921                      124.372
# 3            0.43186              21.066341                       86.663
# 4            0.65862              57.271304                       87.019
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Step 2) Dataset overview and data type inspection

# %%
# Display concise summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   agent_id                     5000 non-null   object
#  1   agent_type                   5000 non-null   object
#  2   model_architecture           5000 non-null   object
#  3   deployment_environment       5000 non-null   object
#  4   task_category                5000 non-null   object
#  5   task_complexity              5000 non-null   int64
#  6   autonomy_level               5000 non-null   int64
#  7   success_rate                 5000 non-null   float64
#  8   accuracy_score               5000 non-null   float64
#  9   efficiency_score             5000 non-null   float64
#  10  execution_time_seconds       5000 non-null   float64
#  11  response_latency_ms          5000 non-null   float64
#  12  memory_usage_mb              5000 non-null   float64
#  13  cpu_usage_percent            5000 non-null   float64
#  14  cost_per_task_cents          5000 non-null   float64
#  15  human_intervention_required  5000 non-null   bool
#  16  error_recovery_rate          5000 non-null   float64
#  17  multimodal_capability        5000 non-null   bool
#  18  edge_compatibility           5000 non-null   bool
#  19  privacy_compliance_score     5000 non-null   float64
#  20  bias_detection_score         5000 non-null   float64
#  21  timestamp                    5000 non-null   object
#  22  data_quality_score           5000 non-null   float64
#  23  performance_index            5000 non-null   float64
#  24  cost_efficiency_ratio        5000 non-null   float64
#  25  autonomous_capability_score  5000 non-null   float64
# dtypes: bool(3), float64(15), int64(2), object(6)
# memory usage: 913.2+ KB

# %%
# Quick statistical overview of numeric columns
df.describe()
# Out:
#        task_complexity  autonomy_level  success_rate  accuracy_score  \
# count      5000.000000     5000.000000   5000.000000     5000.000000
# mean          6.083000        6.030600      0.490683        0.573375
# std           2.143789        2.403085      0.158827        0.127175
# min           2.000000        1.000000      0.300000        0.400000
# 25%           4.000000        4.000000      0.338975        0.465475
# 50%           6.000000        6.000000      0.470050        0.565950
# 75%           8.000000        8.000000      0.613350        0.667925
# max          10.000000       10.000000      0.976500        0.959600
#
#        efficiency_score  execution_time_seconds  response_latency_ms  \
# count       5000.000000             5000.000000          5000.000000
# mean           0.588884               46.224444           899.599622
# std            0.115969               25.997988           803.829179
# min            0.300000                1.000000           100.010000
# 25%            0.501975               26.657500           338.532500
# 50%            0.588950               40.320000           637.680000
# 75%            0.674700               60.182500          1202.357500
# max            0.885500              157.150000          5478.150000
#
#        memory_usage_mb  cpu_usage_percent  cost_per_task_cents  \
# count      5000.000000        5000.000000          5000.000000
# mean        404.438560          68.956920             0.019453
# std         111.743654          19.827232             0.009245
# min         112.900000          10.900000             0.002700
# 25%         322.200000          54.600000             0.012400
# 50%         402.700000          68.500000             0.017500
# 75%         488.325000          83.500000             0.024500
# max         686.600000         133.600000             0.058500
#
#        error_recovery_rate  privacy_compliance_score  bias_detection_score  \
# count          5000.000000               5000.000000           5000.000000
# mean              0.565884                  0.841938              0.774397
# std               0.164149                  0.081324              0.101954
# min               0.300100                  0.700000              0.600200
# 25%               0.426650                  0.772000              0.685275
# 50%               0.547300                  0.842200              0.773800
# 75%               0.690025                  0.913425              0.864325
# max               0.950000                  0.979900              0.950000
#
#        data_quality_score  performance_index  cost_efficiency_ratio  \
# count         5000.000000        5000.000000            5000.000000
# mean             0.863688           0.544951              34.321394
# std              0.066905           0.132550              21.864002
# min              0.750000           0.330000               5.951597
# 25%              0.806400           0.428152              18.107412
# 50%              0.862450           0.536100              28.916278
# 75%              0.922200           0.647397              45.149029
# max              0.979900           0.887470             219.327027
#
#        autonomous_capability_score
# count                  5000.000000
# mean                    102.345902
# std                      16.806164
# min                      56.284000
# 25%                      89.828250
# 50%                     102.633000
# 75%                     116.005000
# max                     147.694000

# %%
# Check unique values for categorical/object columns
print("Unique value counts (for categorical columns):")
cat_cols = df.select_dtypes(include=['object', 'bool']).columns
for col in cat_cols:
    print(f"{col}: {df[col].nunique()} ")
# Out:
# Unique value counts (for categorical columns):
# agent_id: 5000
# agent_type: 16
# model_architecture: 10
# deployment_environment: 6
# task_category: 10
# human_intervention_required: 2
# multimodal_capability: 2
# edge_compatibility: 2
# timestamp: 362

# %%
# Check unique values for numeric columns
print("Unique value counts (for numeric columns):")
cat_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in cat_cols:
    print(f"{col}: {df[col].nunique()} ")
# Out:
# Unique value counts (for numeric columns):
# task_complexity: 9
# autonomy_level: 10
# success_rate: 2832
# accuracy_score: 2710
# efficiency_score: 2992
# execution_time_seconds: 3698
# response_latency_ms: 4929
# memory_usage_mb: 2957
# cpu_usage_percent: 897
# cost_per_task_cents: 459
# error_recovery_rate: 3283
# privacy_compliance_score: 2339
# bias_detection_score: 2660
# data_quality_score: 2069
# performance_index: 4707
# cost_efficiency_ratio: 4998
# autonomous_capability_score: 4557

# %%
df.dtypes
# Out:
# agent_id                        object
# agent_type                      object
# model_architecture              object
# deployment_environment          object
# task_category                   object
# task_complexity                  int64
# autonomy_level                   int64
# success_rate                   float64
# accuracy_score                 float64
# efficiency_score               float64
# execution_time_seconds         float64
# response_latency_ms            float64
# memory_usage_mb                float64
# cpu_usage_percent              float64
# cost_per_task_cents            float64
# human_intervention_required       bool
# error_recovery_rate            float64
# multimodal_capability             bool
# edge_compatibility                bool
# privacy_compliance_score       float64
# bias_detection_score           float64
# timestamp                       object
# data_quality_score             float64
# performance_index              float64
# cost_efficiency_ratio          float64
# autonomous_capability_score    float64
# dtype: object

# %% [markdown]
# ### step 3) Inspect for missing values, duplicates, and inconsistent types

# %%
# Check count of missing (NaN) values in each column
df.isna().sum().sort_values(ascending=False)
# Out:
# agent_id                       0
# agent_type                     0
# cost_efficiency_ratio          0
# performance_index              0
# data_quality_score             0
# timestamp                      0
# bias_detection_score           0
# privacy_compliance_score       0
# edge_compatibility             0
# multimodal_capability          0
# error_recovery_rate            0
# human_intervention_required    0
# cost_per_task_cents            0
# cpu_usage_percent              0
# memory_usage_mb                0
# response_latency_ms            0
# execution_time_seconds         0
# efficiency_score               0
# accuracy_score                 0
# success_rate                   0
# autonomy_level                 0
# task_complexity                0
# task_category                  0
# deployment_environment         0
# model_architecture             0
# autonomous_capability_score    0
# dtype: int64

# %%
# Check duplicate rows in the dataset
duplicates = df.duplicated().sum()
print(f"Total duplicate rows: {duplicates}")
# Out:
# Total duplicate rows: 0

# %% [markdown]
# ### Saving the cleaned dataset

# %%
# Defining the cleaned data path
cleaned_folder = "/Users/srinidhigowda/Desktop/Git-Clones/agentic-cost-performance-analysis/data/cleaned"

# %%
# To make sure the folder exists before saving
if not os.path.exists(cleaned_folder):
    os.makedirs(cleaned_folder)
    print(f"📁 Created folder: {cleaned_folder}")
else:
    print(f"📁 Folder already exists: {cleaned_folder}")
# Out:
# 📁 Folder already exists: /Users/srinidhigowda/Desktop/Git-Clones/agentic-cost-performance-analysis/data/cleaned

# %%
# Define the file name and save the cleaned dataset
cleaned_file_path = os.path.join(cleaned_folder, "cleaned_data.csv")
df.to_csv(cleaned_file_path, index=False)
