# %% [markdown]
# # 03 - Model Training & Optimization
#
# This notebook trains ensemble models, optimizes hyperparameters, and saves the best model for API deployment.
#
# **Course:** DATA 230 (Data Visualization) at SJSU

# %%
import sys
sys.path.append('..')

import pandas as pd
import joblib
from sklearn.model_selection import train_test_split
from src.models.ensemble import EnsembleModel
from src.models.optimization import HyperparameterOptimizer

# Load feature-engineered data
df = pd.read_csv('../data/ml/feature_engineered_data.csv')
print(f"Loaded {len(df)} records")
